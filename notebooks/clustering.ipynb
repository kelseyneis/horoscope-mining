# %%
#import libraries
import numpy as np
from matplotlib import pyplot as plt
import pandas as pd
from sklearn.feature_extraction.text import CountVectorizer

# read in data.
df = pd.read_csv('../horoscope_saved.csv')
df = df[df['category']=='general']
df = df.drop(columns=['category', 'date'])

signs = {'aries': 1, 'taurus': 2, 'gemini': 3, 'cancer': 4, 'leo': 5, 'virgo': 6, 'libra': 7, 'scorpio': 8, 'sagittarius': 9, 'capricorn': 10, 'aquarius': 11, 'pisces': 12}

df['cluster'] = df['sign'].map(signs)
y = np.array(df['cluster'])
X = np.array(df['horoscope'])

# %%
vectorizer = CountVectorizer(stop_words='english')
vectorizer.fit(np.array(X))
X = vectorizer.transform(X)
X = X.toarray()

# %%
from sklearn.decomposition import PCA

pca = PCA(n_components=50)
principalComponents = pca.fit_transform(X)
principalDf = pd.DataFrame(data = principalComponents)

# %%
# Out:
#          0         1         2         3         4         5         6   \
# 0 -0.483863  0.620563  1.574298 -0.604073  0.014200 -0.196422  0.086003
# 1  0.613842 -1.050528  0.492646 -0.084829  1.083196  0.514562  0.272778
# 2 -0.335698 -0.116979 -0.436409 -0.273969  0.351542 -0.597832 -0.114471
# 3 -0.119843  0.026216 -0.242318  0.055632  0.399262 -1.181006  0.183041
# 4 -0.429289  1.231981  1.174022 -0.656744  1.084066 -0.386446  0.505992
#
#          7         8         9   ...        40        41        42        43  \
# 0 -0.341404  0.262872  0.177077  ... -0.229799 -0.270493 -0.149635 -0.420355
# 1 -0.591405 -0.311993 -0.176180  ...  0.014906 -0.191073 -0.065010 -0.073057
# 2 -0.136035 -0.038322 -0.269415  ...  0.254172 -0.201620  0.345497 -0.128266
# 3 -0.173032 -0.138407 -0.202703  ... -0.045020 -0.386268 -0.733123  0.467535
# 4  0.697097  0.089747 -0.309516  ... -0.270481  0.302380  0.156540 -0.188839
#
#          44        45        46        47        48        49
# ...
